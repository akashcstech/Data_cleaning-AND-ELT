# %% [markdown]
# # ELT

# %% [markdown]
# # EXTRACT

# %%
import pandas as pd

# %%
data = pd.read_csv("zomato_cleaned.csv")

# %%
data.head(5)
# Out:
#                     Name  Avialable_Online_order  Avial_Book_table  \
# 0                  Jalsa                    True              True
# 1         Spice Elephant                    True             False
# 2        San Churro Cafe                    True             False
# 3  Addhuri Udupi Bhojana                   False             False
# 4          Grand Village                   False             False
#
#   Rate out of 5  Votes of popularity                        Phone  \
# 0           4.1                  775    08042297555,+919743772233
# 1           4.1                  787                  08041714161
# 2           3.8                  918                +919663487993
# 3           3.7                   88                +919620009302
# 4           3.8                  166  +918026612447,+919901210005
#
#        Location            Rest_type  Approx_cost(for two people)  \
# 0  Banashankari        Casual Dining                          800
# ...

# %% [markdown]
# # Transform

# %%
data.drop(columns="Phone")
# Out:
#                                               Name  Avialable_Online_order  \
# 0                                            Jalsa                    True
# 1                                   Spice Elephant                    True
# 2                                  San Churro Cafe                    True
# 3                            Addhuri Udupi Bhojana                   False
# 4                                    Grand Village                   False
# ...                                            ...                     ...
# 20298                                    SLV Grand                    True
# 20299                           New Shalimar Hotel                   False
# 20300  Nook - Aloft Bengaluru Cessna Business Park                   False
# 20301                             SeeYa Restaurant                   False
# 20302                                      Bhagini                   False
#
#        Avial_Book_table Rate out of 5  Votes of popularity  \
# ...

# %%
data.shape
# Out:
# (20303, 10)

# %% [markdown]
# # Load

# %%
import sqlite3

# %%
conn = sqlite3.connect("zomato.db")

# %%
data.to_sql("zomato_cleaned", conn, if_exists= "replace", index=False)
# Out:
# 20303

# %% [markdown]
# # View IN Sqlite3

# %%
table = pd.read_sql("SELECT * FROM zomato_cleaned LIMIT 5;", conn)

# %%
table
# Out:
#                     Name  Avialable_Online_order  Avial_Book_table  \
# 0                  Jalsa                       1                 1
# 1         Spice Elephant                       1                 0
# 2        San Churro Cafe                       1                 0
# 3  Addhuri Udupi Bhojana                       0                 0
# 4          Grand Village                       0                 0
#
#   Rate out of 5  Votes of popularity                        Phone  \
# 0           4.1                  775    08042297555,+919743772233
# 1           4.1                  787                  08041714161
# 2           3.8                  918                +919663487993
# 3           3.7                   88                +919620009302
# 4           3.8                  166  +918026612447,+919901210005
#
#        Location            Rest_type  Approx_cost(for two people)  \
# 0  Banashankari        Casual Dining                          800
# ...

# %%
conn.commit()

# %%
conn.close()
